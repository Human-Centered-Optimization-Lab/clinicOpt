# %%
import pickle
from desdeo.mcdm.reference_point_method import rpm_solve_solutions

# DESDEO commit: d4fea860f28723583fe6891d03b48fe0770c0399

with open('bug.pkl', 'rb') as f:
    prob = pickle.load(f)

print(prob.get_ideal_point())
print(prob.get_nadir_point())

reference_point = {"f_1": 200, "f_2": 10, "f_3": 1000, "f_4": 0.5}

res = rpm_solve_solutions(prob, reference_point=reference_point)
# Out:
# {'f_1': 179, 'f_2': 0, 'f_3': 0, 'f_4': 1.0}
# {'f_1': 0, 'f_2': 16, 'f_3': 3716.475, 'f_4': 0}
